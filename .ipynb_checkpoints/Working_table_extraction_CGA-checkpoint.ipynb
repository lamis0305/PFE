# %%
import os
import re
import sys
import pandas as pd
import numpy as np
import pdfplumber
import camelot
import warnings
from datetime import datetime
from typing import Tuple, Optional

# Fix Windows console encoding
if sys.platform == "win32":
    import io
    sys.stdout = io.TextIOWrapper(sys.stdout.buffer, encoding='utf-8')

# Configuration
GS_PATH = r"C:\Program Files\gs\gs10.05.1\bin\gswin64c.exe"

# Verify Ghostscript exists
if not os.path.exists(GS_PATH):
    print(f"ERROR: Ghostscript not found at {GS_PATH}")
    print("Please install Ghostscript 10.05.1 from https://www.ghostscript.com/")
    sys.exit(1)

# Configure Camelot
try:
    camelot.__gs_path__ = GS_PATH
    print(f"\nSuccessfully configured Camelot with Ghostscript at: {GS_PATH}")
except Exception as e:
    print(f"\nERROR configuring Camelot: {str(e)}")
    sys.exit(1)

def safe_print(message):
    """Safely print Unicode characters in Windows"""
    try:
        print(message)
    except UnicodeEncodeError:
        print(message.encode('ascii', 'replace').decode('ascii'))

def find_section_boundaries(pdf_path: str) -> Tuple[Optional[int], Optional[int]]:
    filename = os.path.basename(pdf_path)
    year_match = re.search(r'(20\d{2})', filename)
    if not year_match:
        raise ValueError(f"Could not extract year from filename: {filename}")

    year = year_match.group(1)
    end_marker_pattern = re.compile(rf"TUNISIAN\s+INSURANCE\s+MARKET\s+IN\s+{year}", re.IGNORECASE)

    with pdfplumber.open(pdf_path) as pdf:
        last_annexe_page = None
        for i, page in enumerate(pdf.pages):
            text = (page.extract_text() or "").replace("\n", " ")
            if "annexe" in text.lower() or "annexes" in text.lower():
                last_annexe_page = i + 1

        if last_annexe_page is None:
            raise ValueError("No 'annexe' or 'annexes' markers found in document")

        start_page = last_annexe_page + 1
        end_page = None
        
        for i in range(start_page - 1, len(pdf.pages)):
            text = (pdf.pages[i].extract_text() or "").replace("\n", " ")
            if end_marker_pattern.search(text):
                end_page = i
                break

        if end_page is None:
            raise ValueError(f"End marker not found: 'TUNISIAN INSURANCE MARKET IN {year}'")

        return (start_page, end_page + 1)

def extract_tables(pdf_path: str, start_page: int, end_page: int, output_dir: str) -> int:
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    total_tables = 0
    
    with pdfplumber.open(pdf_path) as pdf:
        total_pages = len(pdf.pages)
        safe_print(f"\nStarting table extraction (pages {start_page}-{end_page} of {total_pages})")
        
        for page_num in range(start_page, end_page + 1):
            if page_num > total_pages:
                safe_print(f"Page {page_num} exceeds document length")
                continue
                
            safe_print(f"\n{'='*50}")
            safe_print(f"PROCESSING PAGE {page_num}")
            safe_print(f"{'='*50}")
            
            tables = []
            try:
                # Try lattice mode first
                lattice_tables = camelot.read_pdf(
                    pdf_path,
                    pages=str(page_num),
                    flavor='lattice',
                    strip_text='\n',
                    suppress_stdout=True
                )
                tables.extend([t.df for t in lattice_tables if not t.df.empty])
                
                # Fall back to stream mode if no tables found
                if not tables:
                    stream_tables = camelot.read_pdf(
                        pdf_path,
                        pages=str(page_num),
                        flavor='stream',
                        edge_tol=500,
                        row_tol=10,
                        suppress_stdout=True
                    )
                    tables.extend([t.df for t in stream_tables if not t.df.empty])
                
                # Fall back to pdfplumber if Camelot fails
                if not tables:
                    page = pdf.pages[page_num - 1]
                    plumber_tables = page.extract_tables()
                    if plumber_tables:
                        tables = [pd.DataFrame(table).replace(r'^\s*$', np.nan, regex=True) 
                                for table in plumber_tables]
                
                # Save extracted tables
                for i, table in enumerate(tables, 1):
                    if not table.empty:
                        # Clean the table
                        table = table.replace('', np.nan).dropna(how='all').dropna(axis=1, how='all')
                        if not table.empty:
                            filename = os.path.splitext(os.path.basename(pdf_path))[0]
                            output_file = os.path.join(output_dir, f"{filename}_page_{page_num}_table_{i}.xlsx")
                            table.to_excel(output_file, index=False, header=False)
                            safe_print(f"[OK] Extracted table {i} ({table.shape[1]} cols x {table.shape[0]} rows)")
                            safe_print(f"Saved to: {output_file}")
                            total_tables += 1
                        else:
                            safe_print(f"[SKIP] Empty table {i} after cleaning")
                    else:
                        safe_print(f"[SKIP] Empty table {i}")
                        
            except Exception as e:
                safe_print(f"[ERROR] Processing page {page_num}: {str(e)}")
                continue
                
    safe_print(f"\nExtraction complete! Total tables extracted: {total_tables}")
    return total_tables

def process_pdf(pdf_path: str, output_base_dir: str) -> None:
    filename = os.path.basename(pdf_path)
    safe_print(f"\n\n--- Processing file: {filename} ---")
    
    try:
        # Extract year and create output directory
        year_match = re.search(r'(20\d{2})', filename)
        if not year_match:
            safe_print(f"[ERROR] Could not detect year for: {filename}")
            return
            
        year = year_match.group(1)
        output_dir = os.path.join(output_base_dir, year, "raw_extracted_tables")
        os.makedirs(output_dir, exist_ok=True)
        
        # Find annexes range
        start_page, end_page = find_section_boundaries(pdf_path)
        safe_print(f"Annexes detected: pages {start_page} to {end_page}")
        
        # Extract tables
        extract_tables(pdf_path, start_page, end_page, output_dir)
        
    except Exception as e:
        safe_print(f"[ERROR] Failed to process {filename}: {str(e)}")

def main():
    # Configure paths
    pdf_dir = os.path.join("scraped_pdfs_final_3", "Rapports_CGA")
    output_base_dir = "extracted_tables_CGA"
    log_file = os.path.join(pdf_dir, "log_traitements_rapports_CGA.txt")
    
    # Create output directory if not exists
    os.makedirs(output_base_dir, exist_ok=True)

    # Get processed files
    if os.path.exists(log_file):
        with open(log_file, 'r', encoding='utf-8') as f:
            processed_files = set(line.strip().split('|')[0].strip() for line in f if line.strip())
    else:
        processed_files = set()

    # Process new files
    for filename in os.listdir(pdf_dir):
        if filename.lower().endswith(".pdf") and filename not in processed_files:
            pdf_path = os.path.join(pdf_dir, filename)
            process_pdf(pdf_path, output_base_dir)
            
            # Update log
            with open(log_file, 'a', encoding='utf-8') as f:
                timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                f.write(f"{filename} | {timestamp}\n")
            safe_print(f"[LOG] Added to log: {filename} at {timestamp}")
        else:
            safe_print(f"[SKIP] Already processed: {filename}")

if __name__ == "__main__":
    main()
# Out:
# --- Traitement du fichier : CGA_RAPPORT_FR-ANG2015.pdf ---
# Scanning document to find section boundaries...
# Total pages in document: 106
# Found 'annexes' on page 6
# Found 'annexes' on page 24
# Found 'tunisian insurance market' on page 60
#
# Second 'annexes' found on page 24
# Setting start page to: 25
#
# 'tunisian insurance market' found on page 60
# Setting end page to: 58
#
# Final extraction range: pages 25 to 58
#
# Starting table extraction (pages 25-58 of 106)
#
# ==================================================
# Processing Page 25
# ==================================================
# ✓ Extracted table 1 (5 cols x 53 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_25_table_1.xlsx
#
# ==================================================
# Processing Page 26
# ==================================================
# ✓ Extracted table 1 (5 cols x 50 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_26_table_1.xlsx
# ✓ Extracted table 2 (5 cols x 50 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_26_table_2.xlsx
#
# ==================================================
# Processing Page 27
# ==================================================
# ✓ Extracted table 1 (7 cols x 40 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_27_table_1.xlsx
#
# ==================================================
# Processing Page 28
# ==================================================
# ✓ Extracted table 1 (16 cols x 22 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_28_table_1.xlsx
#
# ==================================================
# Processing Page 29
# ==================================================
# ✓ Extracted table 1 (13 cols x 49 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_29_table_1.xlsx
#
# ==================================================
# Processing Page 30
# ==================================================
# ✓ Extracted table 1 (9 cols x 48 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_30_table_1.xlsx
#
# ==================================================
# Processing Page 31
# ==================================================
# ✓ Extracted table 1 (14 cols x 27 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_31_table_1.xlsx
#
# ==================================================
# Processing Page 32
# ==================================================
# ✓ Extracted table 1 (13 cols x 31 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_32_table_1.xlsx
#
# ==================================================
# Processing Page 33
# ==================================================
# ✓ Extracted table 1 (13 cols x 31 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_33_table_1.xlsx
#
# ==================================================
# Processing Page 34
# ==================================================
# ✓ Extracted table 1 (13 cols x 31 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_34_table_1.xlsx
#
# ==================================================
# Processing Page 35
# ==================================================
# ✓ Extracted table 1 (13 cols x 31 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_35_table_1.xlsx
#
# ==================================================
# Processing Page 36
# ==================================================
# ✓ Extracted table 1 (13 cols x 31 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_36_table_1.xlsx
#
# ==================================================
# Processing Page 37
# ==================================================
# ✓ Extracted table 1 (13 cols x 22 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_37_table_1.xlsx
#
# ==================================================
# Processing Page 38
# ==================================================
# ✓ Extracted table 1 (13 cols x 31 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_38_table_1.xlsx
#
# ==================================================
# Processing Page 39
# ==================================================
# ✓ Extracted table 1 (13 cols x 22 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_39_table_1.xlsx
#
# ==================================================
# Processing Page 40
# ==================================================
# ✓ Extracted table 1 (10 cols x 17 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_40_table_1.xlsx
#
# ==================================================
# Processing Page 41
# ==================================================
# ✓ Extracted table 1 (9 cols x 27 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_41_table_1.xlsx
#
# ==================================================
# Processing Page 42
# ==================================================
# ✓ Extracted table 1 (9 cols x 26 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_42_table_1.xlsx
#
# ==================================================
# Processing Page 43
# ==================================================
# ✓ Extracted table 1 (11 cols x 16 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_43_table_1.xlsx
#
# ==================================================
# Processing Page 44
# ==================================================
# ✓ Extracted table 1 (11 cols x 16 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_44_table_1.xlsx
#
# ==================================================
# Processing Page 45
# ==================================================
# ✓ Extracted table 1 (11 cols x 16 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_45_table_1.xlsx
#
# ==================================================
# Processing Page 46
# ==================================================
# ✓ Extracted table 1 (9 cols x 12 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_46_table_1.xlsx
#
# ==================================================
# Processing Page 47
# ==================================================
# ✓ Extracted table 1 (10 cols x 16 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_47_table_1.xlsx
#
# ==================================================
# Processing Page 48
# ==================================================
# ✓ Extracted table 1 (10 cols x 16 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_48_table_1.xlsx
#
# ==================================================
# Processing Page 49
# ==================================================
# ✓ Extracted table 1 (11 cols x 22 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_49_table_1.xlsx
#
# ==================================================
# Processing Page 50
# ==================================================
# ✓ Extracted table 1 (10 cols x 8 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_50_table_1.xlsx
#
# ==================================================
# Processing Page 51
# ==================================================
# ✓ Extracted table 1 (10 cols x 10 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_51_table_1.xlsx
#
# ==================================================
# Processing Page 52
# ==================================================
# ✓ Extracted table 1 (10 cols x 10 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_52_table_1.xlsx
#
# ==================================================
# Processing Page 53
# ==================================================
# ✓ Extracted table 1 (10 cols x 12 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_53_table_1.xlsx
#
# ==================================================
# Processing Page 54
# ==================================================
# ✓ Extracted table 1 (10 cols x 10 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_54_table_1.xlsx
#
# ==================================================
# Processing Page 55
# ==================================================
# ✓ Extracted table 1 (10 cols x 12 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_55_table_1.xlsx
#
# ==================================================
# Processing Page 56
# ==================================================
# ✓ Extracted table 1 (10 cols x 10 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_56_table_1.xlsx
#
# ==================================================
# Processing Page 57
# ==================================================
# ✓ Extracted table 1 (10 cols x 13 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_57_table_1.xlsx
#
# ==================================================
# Processing Page 58
# ==================================================
# ✓ Extracted table 1 (9 cols x 19 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2015\raw_extracted_tables\page_58_table_1.xlsx
#
# Extraction complete! Total tables extracted: 35
#
#
# --- Traitement du fichier : CGA_RAPPORT_FR_-ANG_2016.pdf ---
# Scanning document to find section boundaries...
# Total pages in document: 106
# Found 'annexes' on page 6
# Found 'annexes' on page 24
# Found 'tunisian insurance market' on page 60
#
# Second 'annexes' found on page 24
# Setting start page to: 25
#
# 'tunisian insurance market' found on page 60
# Setting end page to: 58
#
# Final extraction range: pages 25 to 58
#
# Starting table extraction (pages 25-58 of 106)
#
# ==================================================
# Processing Page 25
# ==================================================
# ✓ Extracted table 1 (5 cols x 53 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_25_table_1.xlsx
#
# ==================================================
# Processing Page 26
# ==================================================
# ✓ Extracted table 1 (5 cols x 50 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_26_table_1.xlsx
# ✓ Extracted table 2 (5 cols x 50 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_26_table_2.xlsx
#
# ==================================================
# Processing Page 27
# ==================================================
# ✓ Extracted table 1 (7 cols x 42 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_27_table_1.xlsx
#
# ==================================================
# Processing Page 28
# ==================================================
# ✓ Extracted table 1 (16 cols x 22 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_28_table_1.xlsx
#
# ==================================================
# Processing Page 29
# ==================================================
# ✓ Extracted table 1 (13 cols x 51 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_29_table_1.xlsx
#
# ==================================================
# Processing Page 30
# ==================================================
# ✓ Extracted table 1 (9 cols x 48 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_30_table_1.xlsx
#
# ==================================================
# Processing Page 31
# ==================================================
# ✓ Extracted table 1 (13 cols x 28 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_31_table_1.xlsx
#
# ==================================================
# Processing Page 32
# ==================================================
# ✓ Extracted table 1 (13 cols x 32 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_32_table_1.xlsx
#
# ==================================================
# Processing Page 33
# ==================================================
# ✓ Extracted table 1 (13 cols x 32 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_33_table_1.xlsx
#
# ==================================================
# Processing Page 34
# ==================================================
# ✓ Extracted table 1 (13 cols x 32 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_34_table_1.xlsx
#
# ==================================================
# Processing Page 35
# ==================================================
# ✓ Extracted table 1 (13 cols x 32 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_35_table_1.xlsx
#
# ==================================================
# Processing Page 36
# ==================================================
# ✓ Extracted table 1 (13 cols x 32 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_36_table_1.xlsx
#
# ==================================================
# Processing Page 37
# ==================================================
# ✓ Extracted table 1 (13 cols x 23 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_37_table_1.xlsx
#
# ==================================================
# Processing Page 38
# ==================================================
# ✓ Extracted table 1 (14 cols x 31 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_38_table_1.xlsx
#
# ==================================================
# Processing Page 39
# ==================================================
# ✓ Extracted table 1 (13 cols x 22 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_39_table_1.xlsx
#
# ==================================================
# Processing Page 40
# ==================================================
# ✓ Extracted table 1 (10 cols x 18 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_40_table_1.xlsx
#
# ==================================================
# Processing Page 41
# ==================================================
# ✓ Extracted table 1 (9 cols x 28 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_41_table_1.xlsx
#
# ==================================================
# Processing Page 42
# ==================================================
# ✓ Extracted table 1 (9 cols x 27 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_42_table_1.xlsx
#
# ==================================================
# Processing Page 43
# ==================================================
# ✓ Extracted table 1 (11 cols x 16 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_43_table_1.xlsx
#
# ==================================================
# Processing Page 44
# ==================================================
# ✓ Extracted table 1 (10 cols x 16 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_44_table_1.xlsx
#
# ==================================================
# Processing Page 45
# ==================================================
# ✓ Extracted table 1 (10 cols x 18 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_45_table_1.xlsx
#
# ==================================================
# Processing Page 46
# ==================================================
# ✓ Extracted table 1 (10 cols x 11 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_46_table_1.xlsx
#
# ==================================================
# Processing Page 47
# ==================================================
# ✓ Extracted table 1 (10 cols x 17 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_47_table_1.xlsx
#
# ==================================================
# Processing Page 48
# ==================================================
# ✓ Extracted table 1 (10 cols x 16 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_48_table_1.xlsx
#
# ==================================================
# Processing Page 49
# ==================================================
# ✓ Extracted table 1 (11 cols x 23 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_49_table_1.xlsx
#
# ==================================================
# Processing Page 50
# ==================================================
# ✓ Extracted table 1 (9 cols x 8 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_50_table_1.xlsx
#
# ==================================================
# Processing Page 51
# ==================================================
# ✓ Extracted table 1 (10 cols x 11 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_51_table_1.xlsx
#
# ==================================================
# Processing Page 52
# ==================================================
# ✓ Extracted table 1 (10 cols x 11 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_52_table_1.xlsx
#
# ==================================================
# Processing Page 53
# ==================================================
# ✓ Extracted table 1 (10 cols x 13 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_53_table_1.xlsx
#
# ==================================================
# Processing Page 54
# ==================================================
# ✓ Extracted table 1 (10 cols x 11 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_54_table_1.xlsx
#
# ==================================================
# Processing Page 55
# ==================================================
# ✓ Extracted table 1 (10 cols x 13 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_55_table_1.xlsx
#
# ==================================================
# Processing Page 56
# ==================================================
# ✓ Extracted table 1 (10 cols x 11 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_56_table_1.xlsx
#
# ==================================================
# Processing Page 57
# ==================================================
# ✓ Extracted table 1 (10 cols x 14 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_57_table_1.xlsx
#
# ==================================================
# Processing Page 58
# ==================================================
# ✓ Extracted table 1 (9 cols x 20 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2016\raw_extracted_tables\page_58_table_1.xlsx
#
# Extraction complete! Total tables extracted: 35
#
#
# --- Traitement du fichier : CGA_RAP_FR_ANG_2014.pdf ---
# Scanning document to find section boundaries...
# Total pages in document: 106
# Found 'annexes' on page 6
# Found 'annexes' on page 24
# Found 'tunisian insurance market' on page 60
#
# Second 'annexes' found on page 24
# Setting start page to: 25
#
# 'tunisian insurance market' found on page 60
# Setting end page to: 58
#
# Final extraction range: pages 25 to 58
#
# Starting table extraction (pages 25-58 of 106)
#
# ==================================================
# Processing Page 25
# ==================================================
# ✓ Extracted table 1 (5 cols x 53 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_25_table_1.xlsx
#
# ==================================================
# Processing Page 26
# ==================================================
# ✓ Extracted table 1 (5 cols x 50 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_26_table_1.xlsx
# ✓ Extracted table 2 (5 cols x 50 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_26_table_2.xlsx
#
# ==================================================
# Processing Page 27
# ==================================================
# ✓ Extracted table 1 (7 cols x 38 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_27_table_1.xlsx
#
# ==================================================
# Processing Page 28
# ==================================================
# ✓ Extracted table 1 (15 cols x 22 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_28_table_1.xlsx
#
# ==================================================
# Processing Page 29
# ==================================================
# ✓ Extracted table 1 (13 cols x 49 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_29_table_1.xlsx
#
# ==================================================
# Processing Page 30
# ==================================================
# ✓ Extracted table 1 (9 cols x 49 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_30_table_1.xlsx
#
# ==================================================
# Processing Page 31
# ==================================================
# ✓ Extracted table 1 (14 cols x 25 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_31_table_1.xlsx
#
# ==================================================
# Processing Page 32
# ==================================================
# ✓ Extracted table 1 (13 cols x 32 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_32_table_1.xlsx
#
# ==================================================
# Processing Page 33
# ==================================================
# ✓ Extracted table 1 (13 cols x 31 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_33_table_1.xlsx
#
# ==================================================
# Processing Page 34
# ==================================================
# ✓ Extracted table 1 (13 cols x 31 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_34_table_1.xlsx
#
# ==================================================
# Processing Page 35
# ==================================================
# ✓ Extracted table 1 (13 cols x 31 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_35_table_1.xlsx
#
# ==================================================
# Processing Page 36
# ==================================================
# ✓ Extracted table 1 (13 cols x 30 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_36_table_1.xlsx
#
# ==================================================
# Processing Page 37
# ==================================================
# ✓ Extracted table 1 (13 cols x 31 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_37_table_1.xlsx
#
# ==================================================
# Processing Page 38
# ==================================================
# ✓ Extracted table 1 (13 cols x 22 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_38_table_1.xlsx
#
# ==================================================
# Processing Page 39
# ==================================================
# ✓ Extracted table 1 (10 cols x 17 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_39_table_1.xlsx
#
# ==================================================
# Processing Page 40
# ==================================================
# ✓ Extracted table 1 (9 cols x 27 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_40_table_1.xlsx
#
# ==================================================
# Processing Page 41
# ==================================================
# ✓ Extracted table 1 (9 cols x 27 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_41_table_1.xlsx
#
# ==================================================
# Processing Page 42
# ==================================================
# ✓ Extracted table 1 (11 cols x 16 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_42_table_1.xlsx
#
# ==================================================
# Processing Page 43
# ==================================================
# ✓ Extracted table 1 (11 cols x 16 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_43_table_1.xlsx
#
# ==================================================
# Processing Page 44
# ==================================================
# ✓ Extracted table 1 (11 cols x 16 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_44_table_1.xlsx
#
# ==================================================
# Processing Page 45
# ==================================================
# ✓ Extracted table 1 (9 cols x 12 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_45_table_1.xlsx
#
# ==================================================
# Processing Page 46
# ==================================================
# ✓ Extracted table 1 (10 cols x 16 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_46_table_1.xlsx
#
# ==================================================
# Processing Page 47
# ==================================================
# ✓ Extracted table 1 (10 cols x 16 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_47_table_1.xlsx
#
# ==================================================
# Processing Page 48
# ==================================================
# ✓ Extracted table 1 (11 cols x 22 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_48_table_1.xlsx
#
# ==================================================
# Processing Page 49
# ==================================================
# ✓ Extracted table 1 (10 cols x 8 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_49_table_1.xlsx
#
# ==================================================
# Processing Page 50
# ==================================================
# ✓ Extracted table 1 (10 cols x 10 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_50_table_1.xlsx
#
# ==================================================
# Processing Page 51
# ==================================================
# ✓ Extracted table 1 (10 cols x 9 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_51_table_1.xlsx
#
# ==================================================
# Processing Page 52
# ==================================================
# ✓ Extracted table 1 (10 cols x 11 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_52_table_1.xlsx
#
# ==================================================
# Processing Page 53
# ==================================================
# ✓ Extracted table 1 (10 cols x 10 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_53_table_1.xlsx
#
# ==================================================
# Processing Page 54
# ==================================================
# ✓ Extracted table 1 (10 cols x 12 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_54_table_1.xlsx
#
# ==================================================
# Processing Page 55
# ==================================================
# ✓ Extracted table 1 (10 cols x 10 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_55_table_1.xlsx
#
# ==================================================
# Processing Page 56
# ==================================================
# ✓ Extracted table 1 (10 cols x 13 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_56_table_1.xlsx
#
# ==================================================
# Processing Page 57
# ==================================================
# ✓ Extracted table 1 (9 cols x 19 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_57_table_1.xlsx
#
# ==================================================
# Processing Page 58
# ==================================================
# ✓ Extracted table 1 (9 cols x 19 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2014\raw_extracted_tables\page_58_table_1.xlsx
#
# Extraction complete! Total tables extracted: 35
#
#
# --- Traitement du fichier : rapport_annuel__FR_2013.pdf ---
# Scanning document to find section boundaries...
# Total pages in document: 30
# Found 'annexes' on page 3
# Found 'annexes' on page 11
#
# Second 'annexes' found on page 11
# Setting start page to: 12
#
# Could not find 'tunisian insurance market' marker
#
# Failed to determine section boundaries automatically
# Erreur : impossible de déterminer les pages d'annexes.
#
#
# --- Traitement du fichier : Rapport_CGA_FR-ANG_-_2018_final.pdf ---
# Scanning document to find section boundaries...
# Total pages in document: 108
# Found 'annexes' on page 5
# Found 'annexes' on page 31
# Found 'tunisian insurance market' on page 64
#
# Second 'annexes' found on page 31
# Setting start page to: 32
#
# 'tunisian insurance market' found on page 64
# Setting end page to: 62
#
# Final extraction range: pages 32 to 62
#
# Starting table extraction (pages 32-62 of 108)
#
# ==================================================
# Processing Page 32
# ==================================================
# ✓ Extracted table 1 (7 cols x 44 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_32_table_1.xlsx
#
# ==================================================
# Processing Page 33
# ==================================================
# ✓ Extracted table 1 (3 cols x 28 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_33_table_1.xlsx
# ✓ Extracted table 2 (1 cols x 27 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_33_table_2.xlsx
# ✓ Extracted table 3 (3 cols x 3 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_33_table_3.xlsx
#
# ==================================================
# Processing Page 34
# ==================================================
# ✓ Extracted table 1 (13 cols x 48 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_34_table_1.xlsx
#
# ==================================================
# Processing Page 35
# ==================================================
# ✓ Extracted table 1 (9 cols x 48 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_35_table_1.xlsx
#
# ==================================================
# Processing Page 36
# ==================================================
# ✓ Extracted table 1 (13 cols x 27 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_36_table_1.xlsx
#
# ==================================================
# Processing Page 37
# ==================================================
# ✓ Extracted table 1 (13 cols x 27 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_37_table_1.xlsx
#
# ==================================================
# Processing Page 38
# ==================================================
# ✓ Extracted table 1 (13 cols x 27 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_38_table_1.xlsx
#
# ==================================================
# Processing Page 39
# ==================================================
# ✓ Extracted table 1 (13 cols x 27 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_39_table_1.xlsx
#
# ==================================================
# Processing Page 40
# ==================================================
# ✓ Extracted table 1 (13 cols x 19 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_40_table_1.xlsx
#
# ==================================================
# Processing Page 41
# ==================================================
# ✓ Extracted table 1 (13 cols x 27 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_41_table_1.xlsx
#
# ==================================================
# Processing Page 42
# ==================================================
# ✓ Extracted table 1 (13 cols x 21 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_42_table_1.xlsx
#
# ==================================================
# Processing Page 43
# ==================================================
# ✓ Extracted table 1 (13 cols x 19 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_43_table_1.xlsx
#
# ==================================================
# Processing Page 44
# ==================================================
# ✓ Extracted table 1 (13 cols x 27 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_44_table_1.xlsx
#
# ==================================================
# Processing Page 45
# ==================================================
# ✓ Extracted table 1 (13 cols x 13 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_45_table_1.xlsx
#
# ==================================================
# Processing Page 46
# ==================================================
# ✓ Extracted table 1 (10 cols x 17 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_46_table_1.xlsx
#
# ==================================================
# Processing Page 47
# ==================================================
# ✓ Extracted table 1 (9 cols x 26 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_47_table_1.xlsx
#
# ==================================================
# Processing Page 48
# ==================================================
# ✓ Extracted table 1 (9 cols x 26 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_48_table_1.xlsx
#
# ==================================================
# Processing Page 49
# ==================================================
# ✓ Extracted table 1 (10 cols x 1 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_49_table_1.xlsx
# ✓ Extracted table 2 (12 cols x 3 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_49_table_2.xlsx
#
# ==================================================
# Processing Page 50
# ==================================================
# ✓ Extracted table 1 (10 cols x 1 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_50_table_1.xlsx
# ✓ Extracted table 2 (12 cols x 3 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_50_table_2.xlsx
#
# ==================================================
# Processing Page 51
# ==================================================
# ✓ Extracted table 1 (11 cols x 1 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_51_table_1.xlsx
# ✓ Extracted table 2 (12 cols x 3 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_51_table_2.xlsx
#
# ==================================================
# Processing Page 52
# ==================================================
# ✓ Extracted table 1 (3 cols x 3 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_52_table_1.xlsx
# ✓ Extracted table 2 (5 cols x 3 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_52_table_2.xlsx
#
# ==================================================
# Processing Page 53
# ==================================================
# ✓ Extracted table 1 (3 cols x 5 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_53_table_1.xlsx
# ✓ Extracted table 2 (5 cols x 5 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_53_table_2.xlsx
#
# ==================================================
# Processing Page 54
# ==================================================
# ✓ Extracted table 1 (5 cols x 3 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_54_table_1.xlsx
#
# ==================================================
# Processing Page 55
# ==================================================
# ✓ Extracted table 1 (10 cols x 1 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_55_table_1.xlsx
# ✓ Extracted table 2 (11 cols x 3 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_55_table_2.xlsx
#
# ==================================================
# Processing Page 56
# ==================================================
# ✓ Extracted table 1 (10 cols x 1 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_56_table_1.xlsx
# ✓ Extracted table 2 (11 cols x 3 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_56_table_2.xlsx
#
# ==================================================
# Processing Page 57
# ==================================================
# ✓ Extracted table 1 (10 cols x 1 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_57_table_1.xlsx
# ✓ Extracted table 2 (11 cols x 3 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_57_table_2.xlsx
#
# ==================================================
# Processing Page 58
# ==================================================
# ✓ Extracted table 1 (10 cols x 1 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_58_table_1.xlsx
# ✓ Extracted table 2 (11 cols x 2 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_58_table_2.xlsx
#
# ==================================================
# Processing Page 59
# ==================================================
# ✓ Extracted table 1 (10 cols x 1 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_59_table_1.xlsx
# ✓ Extracted table 2 (11 cols x 3 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_59_table_2.xlsx
#
# ==================================================
# Processing Page 60
# ==================================================
# ✓ Extracted table 1 (10 cols x 1 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_60_table_1.xlsx
# ✓ Extracted table 2 (11 cols x 3 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_60_table_2.xlsx
#
# ==================================================
# Processing Page 61
# ==================================================
# ✓ Extracted table 1 (9 cols x 16 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_61_table_1.xlsx
#
# ==================================================
# Processing Page 62
# ==================================================
# ✓ Extracted table 1 (9 cols x 16 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2018\raw_extracted_tables\page_62_table_1.xlsx
#
# Extraction complete! Total tables extracted: 44
#
#
# --- Traitement du fichier : RAPPORT_CGA_FR_ANG_2020.pdf ---
# Scanning document to find section boundaries...
# Total pages in document: 126
# Found 'annexes' on page 7
# Found 'annexes' on page 46
# Found 'tunisian insurance market' on page 76
#
# Second 'annexes' found on page 46
# Setting start page to: 47
#
# 'tunisian insurance market' found on page 76
# Setting end page to: 74
#
# Final extraction range: pages 47 to 74
#
# Starting table extraction (pages 47-74 of 126)
#
# ==================================================
# Processing Page 47
# ==================================================
# ✓ Extracted table 1 (7 cols x 44 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_47_table_1.xlsx
#
# ==================================================
# Processing Page 48
# ==================================================
# ✓ Extracted table 1 (17 cols x 23 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_48_table_1.xlsx
#
# ==================================================
# Processing Page 49
# ==================================================
# ✓ Extracted table 1 (13 cols x 30 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_49_table_1.xlsx
#
# ==================================================
# Processing Page 50
# ==================================================
# ✓ Extracted table 1 (13 cols x 28 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_50_table_1.xlsx
#
# ==================================================
# Processing Page 51
# ==================================================
# ✓ Extracted table 1 (13 cols x 28 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_51_table_1.xlsx
#
# ==================================================
# Processing Page 52
# ==================================================
# ✓ Extracted table 1 (13 cols x 28 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_52_table_1.xlsx
#
# ==================================================
# Processing Page 53
# ==================================================
# ✓ Extracted table 1 (13 cols x 28 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_53_table_1.xlsx
#
# ==================================================
# Processing Page 54
# ==================================================
# ✓ Extracted table 1 (13 cols x 28 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_54_table_1.xlsx
#
# ==================================================
# Processing Page 55
# ==================================================
# ✓ Extracted table 1 (13 cols x 21 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_55_table_1.xlsx
#
# ==================================================
# Processing Page 56
# ==================================================
# ✓ Extracted table 1 (13 cols x 20 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_56_table_1.xlsx
#
# ==================================================
# Processing Page 57
# ==================================================
# ✓ Extracted table 1 (13 cols x 28 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_57_table_1.xlsx
#
# ==================================================
# Processing Page 58
# ==================================================
# ✓ Extracted table 1 (13 cols x 13 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_58_table_1.xlsx
#
# ==================================================
# Processing Page 59
# ==================================================
# ✓ Extracted table 1 (10 cols x 17 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_59_table_1.xlsx
#
# ==================================================
# Processing Page 60
# ==================================================
# ✓ Extracted table 1 (9 cols x 27 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_60_table_1.xlsx
#
# ==================================================
# Processing Page 61
# ==================================================
# ✓ Extracted table 1 (9 cols x 25 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_61_table_1.xlsx
#
# ==================================================
# Processing Page 62
# ==================================================
# ✓ Extracted table 1 (10 cols x 15 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_62_table_1.xlsx
#
# ==================================================
# Processing Page 63
# ==================================================
# ✓ Extracted table 1 (10 cols x 15 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_63_table_1.xlsx
#
# ==================================================
# Processing Page 64
# ==================================================
# ✓ Extracted table 1 (10 cols x 15 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_64_table_1.xlsx
#
# ==================================================
# Processing Page 65
# ==================================================
# ✓ Extracted table 1 (9 cols x 11 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_65_table_1.xlsx
#
# ==================================================
# Processing Page 66
# ==================================================
# ✓ Extracted table 1 (9 cols x 12 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_66_table_1.xlsx
#
# ==================================================
# Processing Page 67
# ==================================================
# ✓ Extracted table 1 (9 cols x 8 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_67_table_1.xlsx
#
# ==================================================
# Processing Page 68
# ==================================================
# ✓ Extracted table 1 (9 cols x 8 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_68_table_1.xlsx
#
# ==================================================
# Processing Page 69
# ==================================================
# ✓ Extracted table 1 (9 cols x 10 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_69_table_1.xlsx
#
# ==================================================
# Processing Page 70
# ==================================================
# ✓ Extracted table 1 (9 cols x 8 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_70_table_1.xlsx
#
# ==================================================
# Processing Page 71
# ==================================================
# ✓ Extracted table 1 (9 cols x 10 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_71_table_1.xlsx
#
# ==================================================
# Processing Page 72
# ==================================================
# ✓ Extracted table 1 (9 cols x 8 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_72_table_1.xlsx
#
# ==================================================
# Processing Page 73
# ==================================================
# ✓ Extracted table 1 (9 cols x 11 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2020\raw_extracted_tables\page_73_table_1.xlsx
#
# ==================================================
# Processing Page 74
# ==================================================
# ...
#
# Could not find 'tunisian insurance market' marker
#
# Failed to determine section boundaries automatically
# Erreur : impossible de déterminer les pages d'annexes.
#
#
# --- Traitement du fichier : Rapport_FR_2011.pdf ---
# Scanning document to find section boundaries...
# Total pages in document: 45
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Could not find second 'annexes' occurrence
#
# Could not find 'tunisian insurance market' marker
#
# Failed to determine section boundaries automatically
# Erreur : impossible de déterminer les pages d'annexes.
#
#
# --- Traitement du fichier : Rapport_FR_2012.pdf ---
# Scanning document to find section boundaries...
# Total pages in document: 85
# Found 'annexes' on page 4
# Found 'tunisian insurance market' on page 5
# Found 'annexes' on page 19
#
# Second 'annexes' found on page 19
# Setting start page to: 20
#
# 'tunisian insurance market' found on page 5
# Setting end page to: 3
#
# ERROR: Invalid page range (start_page >= end_page)
# Erreur : impossible de déterminer les pages d'annexes.
#
#
# --- Traitement du fichier : rapport_FR___ANG_2017.pdf ---
# Scanning document to find section boundaries...
# Total pages in document: 115
# Found 'tunisian insurance market' on page 1
# Found 'annexes' on page 6
# Found 'annexes' on page 30
#
# Second 'annexes' found on page 30
# Setting start page to: 31
#
# 'tunisian insurance market' found on page 1
# Setting end page to: 1
#
# ERROR: Invalid page range (start_page >= end_page)
# Erreur : impossible de déterminer les pages d'annexes.
#
#
# --- Traitement du fichier : RAP_CGA_FR_ANG_2021_nouvelle_version.pdf ---
# Scanning document to find section boundaries...
# Total pages in document: 104
# Found 'annexes' on page 6
# Found 'annexes' on page 41
# Found 'annexes' on page 42
# Found 'tunisian insurance market' on page 64
#
# Second 'annexes' found on page 41
# Setting start page to: 42
#
# 'tunisian insurance market' found on page 64
# Setting end page to: 62
#
# Final extraction range: pages 42 to 62
#
# Starting table extraction (pages 42-62 of 104)
#
# ==================================================
# Processing Page 42
# ==================================================
# ✓ Extracted table 1 (2 cols x 3 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_42_table_1.xlsx
#
# ==================================================
# Processing Page 43
# ==================================================
# ✓ Extracted table 1 (7 cols x 44 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_43_table_1.xlsx
#
# ==================================================
# Processing Page 44
# ==================================================
# ✓ Extracted table 1 (17 cols x 23 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_44_table_1.xlsx
#
# ==================================================
# Processing Page 45
# ==================================================
# ✓ Extracted table 1 (13 cols x 30 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_45_table_1.xlsx
#
# ==================================================
# Processing Page 46
# ==================================================
# ✓ Extracted table 1 (10 cols x 17 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_46_table_1.xlsx
#
# ==================================================
# Processing Page 47
# ==================================================
# ✓ Extracted table 1 (9 cols x 27 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_47_table_1.xlsx
#
# ==================================================
# Processing Page 48
# ==================================================
# ✓ Extracted table 1 (9 cols x 25 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_48_table_1.xlsx
#
# ==================================================
# Processing Page 49
# ==================================================
# ✓ Extracted table 1 (10 cols x 15 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_49_table_1.xlsx
#
# ==================================================
# Processing Page 50
# ==================================================
# ✓ Extracted table 1 (10 cols x 15 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_50_table_1.xlsx
#
# ==================================================
# Processing Page 51
# ==================================================
# ✓ Extracted table 1 (10 cols x 15 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_51_table_1.xlsx
#
# ==================================================
# Processing Page 52
# ==================================================
# ✓ Extracted table 1 (9 cols x 11 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_52_table_1.xlsx
#
# ==================================================
# Processing Page 53
# ==================================================
# ✓ Extracted table 1 (9 cols x 12 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_53_table_1.xlsx
#
# ==================================================
# Processing Page 54
# ==================================================
# ✓ Extracted table 1 (9 cols x 8 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_54_table_1.xlsx
#
# ==================================================
# Processing Page 55
# ==================================================
# ✓ Extracted table 1 (9 cols x 8 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_55_table_1.xlsx
#
# ==================================================
# Processing Page 56
# ==================================================
# ✓ Extracted table 1 (9 cols x 10 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_56_table_1.xlsx
#
# ==================================================
# Processing Page 57
# ==================================================
# ✓ Extracted table 1 (9 cols x 8 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_57_table_1.xlsx
#
# ==================================================
# Processing Page 58
# ==================================================
# ✓ Extracted table 1 (9 cols x 10 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_58_table_1.xlsx
#
# ==================================================
# Processing Page 59
# ==================================================
# ✓ Extracted table 1 (9 cols x 8 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_59_table_1.xlsx
#
# ==================================================
# Processing Page 60
# ==================================================
# ✓ Extracted table 1 (9 cols x 11 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_60_table_1.xlsx
#
# ==================================================
# Processing Page 61
# ==================================================
# ✓ Extracted table 1 (9 cols x 16 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_61_table_1.xlsx
#
# ==================================================
# Processing Page 62
# ==================================================
# ✓ Extracted table 1 (9 cols x 16 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2021\raw_extracted_tables\page_62_table_1.xlsx
#
# Extraction complete! Total tables extracted: 21
#
#
# --- Traitement du fichier : RAP_CGA_FR_ANG_2022.pdf ---
# Scanning document to find section boundaries...
# Total pages in document: 101
# Found 'annexes' on page 4
# Found 'annexes' on page 39
# Found 'annexes' on page 40
# Found 'tunisian insurance market' on page 62
#
# Second 'annexes' found on page 39
# Setting start page to: 40
#
# 'tunisian insurance market' found on page 62
# Setting end page to: 60
#
# Final extraction range: pages 40 to 60
#
# Starting table extraction (pages 40-60 of 101)
#
# ==================================================
# Processing Page 40
# ==================================================
# ✓ Extracted table 1 (2 cols x 3 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_40_table_1.xlsx
#
# ==================================================
# Processing Page 41
# ==================================================
# ✓ Extracted table 1 (6 cols x 44 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_41_table_1.xlsx
#
# ==================================================
# Processing Page 42
# ==================================================
# ✓ Extracted table 1 (17 cols x 23 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_42_table_1.xlsx
#
# ==================================================
# Processing Page 43
# ==================================================
# ✓ Extracted table 1 (13 cols x 29 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_43_table_1.xlsx
#
# ==================================================
# Processing Page 44
# ==================================================
# ✓ Extracted table 1 (10 cols x 15 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_44_table_1.xlsx
#
# ==================================================
# Processing Page 45
# ==================================================
# ✓ Extracted table 1 (10 cols x 28 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_45_table_1.xlsx
#
# ==================================================
# Processing Page 46
# ==================================================
# ✓ Extracted table 1 (10 cols x 25 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_46_table_1.xlsx
#
# ==================================================
# Processing Page 47
# ==================================================
# ✓ Extracted table 1 (10 cols x 15 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_47_table_1.xlsx
#
# ==================================================
# Processing Page 48
# ==================================================
# ✓ Extracted table 1 (10 cols x 15 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_48_table_1.xlsx
#
# ==================================================
# Processing Page 49
# ==================================================
# ✓ Extracted table 1 (10 cols x 15 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_49_table_1.xlsx
#
# ==================================================
# Processing Page 50
# ==================================================
# ✓ Extracted table 1 (9 cols x 11 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_50_table_1.xlsx
#
# ==================================================
# Processing Page 51
# ==================================================
# ✓ Extracted table 1 (9 cols x 12 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_51_table_1.xlsx
#
# ==================================================
# Processing Page 52
# ==================================================
# ✓ Extracted table 1 (9 cols x 8 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_52_table_1.xlsx
#
# ==================================================
# Processing Page 53
# ==================================================
# ✓ Extracted table 1 (9 cols x 8 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_53_table_1.xlsx
#
# ==================================================
# Processing Page 54
# ==================================================
# ✓ Extracted table 1 (9 cols x 10 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_54_table_1.xlsx
#
# ==================================================
# Processing Page 55
# ==================================================
# ✓ Extracted table 1 (9 cols x 8 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_55_table_1.xlsx
#
# ==================================================
# Processing Page 56
# ==================================================
# ✓ Extracted table 1 (9 cols x 10 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_56_table_1.xlsx
#
# ==================================================
# Processing Page 57
# ==================================================
# ✓ Extracted table 1 (9 cols x 8 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_57_table_1.xlsx
#
# ==================================================
# Processing Page 58
# ==================================================
# ✓ Extracted table 1 (9 cols x 11 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_58_table_1.xlsx
#
# ==================================================
# Processing Page 59
# ==================================================
# ✓ Extracted table 1 (9 cols x 16 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_59_table_1.xlsx
#
# ==================================================
# Processing Page 60
# ==================================================
# ✓ Extracted table 1 (9 cols x 16 rows)
# Saved to: C:\Users\DELL\SCRAPING_PFE\extracted_tables_CGA\2022\raw_extracted_tables\page_60_table_1.xlsx
#
# Extraction complete! Total tables extracted: 21
