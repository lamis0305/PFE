# %%
# %run master_pipeline.py
# Out:
# ...
# STEP 1: Downloading new PDF reports
# ...
#
# ...
# RUNNING: python download_pdfs_mailing_FINAL.py
#
# --------------------------------------------------
# Recherche des PDFs: Rapports FTUSA sur les indicateurs de marché
# URL: https://www.ftusanet.org/indicateurs-du-marche-2/
#
# Analyse spécifique du site FTUSA : https://www.ftusanet.org/indicateurs-du-marche-2/
#
# Tentative 1/1
#
#   [ATTEMPT 1/3] Downloading Rapport-FTUSA-2022.pdf
#   URL: https://www.ftusanet.org/wp-content/uploads/2023/09/Rapport-FTUSA-2022-1.pdf
#   Timeout: 30s
#   File size: 2.11MB
#   Downloading: 0.4% | 0.04 MB/s
#   Downloading: 0.7% | 0.08 MB/s
#   Downloading: 1.1% | 0.12 MB/s
#   Downloading: 1.5% | 0.16 MB/s
#   Downloading: 1.9% | 0.16 MB/s
#   Downloading: 2.2% | 0.18 MB/s
#   Downloading: 2.6% | 0.21 MB/s
#   Downloading: 3.0% | 0.24 MB/s
#   Downloading: 3.3% | 0.27 MB/s
#   Downloading: 3.7% | 0.23 MB/s
#   Downloading: 4.1% | 0.24 MB/s
#   Downloading: 4.5% | 0.27 MB/s
#   Downloading: 4.8% | 0.29 MB/s
# ...
