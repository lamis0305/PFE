# %%
import os
import pandas as pd
import re
import time
from datetime import datetime
from pathlib import Path

# Configuration
INPUT_DIR = os.path.join("extracted_tables_CGA")
OUTPUT_DIR = os.path.join("fully_cleaned_tables_CGA")
LOG_FILE = os.path.join(OUTPUT_DIR, "log_cleaning_CGA.txt")

def setup_directories():
    """Create necessary directories if they don't exist"""
    os.makedirs(INPUT_DIR, exist_ok=True)
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    if not os.path.exists(LOG_FILE):
        with open(LOG_FILE, 'w') as f:
            f.write("filename|status|timestamp|output_file\n")

def get_processed_files():
    """Get dictionary of already processed files"""
    processed = {}
    if os.path.exists(LOG_FILE):
        with open(LOG_FILE, 'r') as f:
            for line in f.readlines()[1:]:  # Skip header
                if line.strip():
                    parts = line.strip().split('|')
                    if len(parts) >= 3:
                        processed[parts[0]] = {
                            'status': parts[1],
                            'timestamp': parts[2],
                            'output_file': parts[3] if len(parts) > 3 else None
                        }
    return processed

def log_processing(filename, status, output_file=None):
    """Log a processing attempt"""
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    with open(LOG_FILE, 'a') as f:
        f.write(f"{filename}|{status}|{timestamp}|{output_file or ''}\n")

def needs_processing(input_file, processed_files):
    """Check if file needs processing"""
    if not os.path.exists(input_file):
        return False
        
    filename = os.path.basename(input_file)
    
    # New file needs processing
    if filename not in processed_files:
        return True
        
    # File modified since last processing
    input_mtime = os.path.getmtime(input_file)
    log_time = datetime.strptime(
        processed_files[filename]['timestamp'], 
        "%Y-%m-%d %H:%M:%S"
    ).timestamp()
    
    return input_mtime > log_time

def clean_filename(text):
    """Sanitize filename"""
    text = str(text).strip()
    text = re.sub(r'[\\/*?:"<>|]', "", text)
    text = re.sub(r'\s+', '_', text)
    return text[:100]

def process_cga_file(input_path, output_dir):
    """Process a single CGA file with enhanced error handling"""
    filename = os.path.basename(input_path)
    try:
        # Verify input file exists
        if not os.path.exists(input_path):
            raise FileNotFoundError(f"Input file not found: {input_path}")
        
        # Read with explicit handling of potential errors
        try:
            df = pd.read_excel(input_path, header=None, engine='openpyxl')
        except Exception as e:
            raise ValueError(f"Error reading Excel file: {str(e)}")
        
        # Step 1: Remove rows containing 'annexe'
        df = df[~df.apply(lambda row: row.astype(str).str.lower().str.contains("annexe").any(), axis=1)]
        df = df.reset_index(drop=True)

        # Step 2: Cut at first row with >15 words
        def count_words(row):
            words = []
            for cell in row:
                if isinstance(cell, str):
                    words += cell.strip().split()
            return len(words)
            
        cut_idx = df[df.apply(count_words, axis=1) > 15].index.min()
        if pd.notna(cut_idx):
            df = df.iloc[:cut_idx]
        df = df.reset_index(drop=True)

        # Step 3: Rename file using one-cell header if available
        rename_header = df.iloc[0].dropna().astype(str).tolist()
        if len(rename_header) == 1:
            new_name = clean_filename(rename_header[0]) + ".xlsx"
            df = df[1:].reset_index(drop=True)
        else:
            new_name = filename

        # Step 4: Remove row if it contains (M.D)
        if "(M.D)" in df.iloc[0].astype(str).values:
            df = df[1:].reset_index(drop=True)

        # Step 5: Build header from rows 0, 1, and optionally 2
        header_rows = []
        max_header_rows = 3
        for offset in range(max_header_rows):
            if offset >= len(df):
                break
            row = df.iloc[offset]
            row_str = row.astype(str)
            numeric_count = sum(row_str.str.contains(r"\d").fillna(False))
            if offset == 2 and numeric_count >= len(row) // 2:
                break
            header_rows.append(row.tolist())

        # Build final header
        final_header = []
        for col in range(df.shape[1]):
            parts = [
                str(header_rows[row][col]).strip()
                for row in range(len(header_rows))
                if col < len(header_rows[row]) and str(header_rows[row][col]).strip() != ""
            ]
            final_header.append(" ".join(parts).strip())

        # Apply header and remove header rows
        df.columns = final_header
        df = df[len(header_rows):].reset_index(drop=True)

        # Ensure output directory exists
        os.makedirs(output_dir, exist_ok=True)
        
        # Generate output path
        output_filename = clean_filename(filename)  # Or your naming logic
        output_path = os.path.join(output_dir, output_filename)
        
        # Save with explicit error handling
        try:
            df.to_excel(output_path, index=False, engine='openpyxl')
            return True, output_filename
        except Exception as e:
            raise IOError(f"Error saving file: {str(e)}")
            
    except Exception as e:
        print(f"ERROR processing {filename}: {str(e)}")
        return False, None

def main():
    print("Setting up CGA directories...")
    setup_directories()
    
    print("Loading processed files log...")
    processed_files = get_processed_files()
    
    total_files = 0
    processed_count = 0
    skipped_count = 0
    failed_count = 0
    
    print("\nStarting CGA file processing...")
    for root, dirs, files in os.walk(INPUT_DIR):
        for filename in files:
            if filename.lower().endswith('.xlsx'):
                total_files += 1
                input_path = os.path.join(root, filename)
                
                if not needs_processing(input_path, processed_files):
                    print(f"[SKIP] Already processed: {filename}")
                    skipped_count += 1
                    continue
                
                print(f"\nProcessing: {filename}")
                success, output_filename = process_cga_file(input_path, OUTPUT_DIR)
                
                if success:
                    log_processing(filename, "SUCCESS", output_filename)
                    processed_count += 1
                    print(f"-> Saved as: {output_filename}")
                else:
                    log_processing(filename, "FAILED")
                    failed_count += 1
                    print("-> Processing failed")
    
    print("\nCGA Processing summary:")
    print(f"Total files found: {total_files}")
    print(f"Successfully processed: {processed_count}")
    print(f"Skipped (already processed): {skipped_count}")
    print(f"Failed: {failed_count}")
    
    # Verify output
    output_files = [f for f in os.listdir(OUTPUT_DIR) if f.lower().endswith('.xlsx')]
    print(f"\nFound {len(output_files)} cleaned files in output directory")

if __name__ == "__main__":
    start_time = time.time()
    main()
    print(f"\nTotal execution time: {time.time() - start_time:.2f} seconds")
# Out:
# Setting up CGA directories...
# Loading processed files log...
#
# Starting CGA file processing...
# [SKIP] Already processed: CGA_RAP_FR_ANG_2014_page_28_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_29_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_29_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_30_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_30_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_31_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_31_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_32_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_32_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_33_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_33_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_34_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_34_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_35_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_35_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_36_table_1.xlsx
# ERROR processing CGA_RAP_FR_ANG_2014_page_36_table_1.xlsx: single positional indexer is out-of-bounds
# → Processing failed
#
# Processing: CGA_RAP_FR_ANG_2014_page_37_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_37_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_38_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_38_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_39_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_39_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_40_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_40_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_41_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_41_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_42_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_42_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_43_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_43_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_44_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_44_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_45_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_45_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_46_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_46_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_47_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_47_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_48_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_48_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_49_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_49_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_50_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_50_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_51_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_51_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_52_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_52_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_53_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_53_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_54_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_54_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_55_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_55_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_56_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_56_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_57_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_57_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_58_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_58_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_60_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_60_table_1.xlsx
#
# Processing: CGA_RAP_FR_ANG_2014_page_61_table_1.xlsx
# → Saved as: CGA_RAP_FR_ANG_2014_page_61_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_28_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_28_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_29_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_29_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_30_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_30_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_31_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_31_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_32_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_32_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_33_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_33_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_34_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_34_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_35_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_35_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_36_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_36_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_37_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_37_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_38_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_38_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_39_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_39_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_40_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_40_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_41_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_41_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_42_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_42_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_43_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_43_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_44_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_44_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_45_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_45_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_46_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_46_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_47_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_47_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_48_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_48_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_49_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_49_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_50_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_50_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_51_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_51_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_52_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_52_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_53_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_53_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_54_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_54_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_55_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_55_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_56_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_56_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_57_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_57_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_58_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_58_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_59_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_59_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_60_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_60_table_1.xlsx
#
# Processing: CGA_RAPPORT_FR-ANG2015_page_61_table_1.xlsx
# → Saved as: CGA_RAPPORT_FR-ANG2015_page_61_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_28_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_28_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_29_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_29_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_30_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_30_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_31_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_31_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_32_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_32_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_33_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_33_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_34_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_34_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_35_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_35_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_36_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_36_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_37_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_37_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_38_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_38_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_39_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_39_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_40_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_40_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_41_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_41_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_42_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_42_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_43_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_43_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_44_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_44_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_45_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_45_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_46_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_46_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_47_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_47_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_48_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_48_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_49_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_49_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_50_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_50_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_51_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_51_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_52_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_52_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_53_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_53_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_54_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_54_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_55_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_55_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_56_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_56_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_57_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_57_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_58_table_1.xlsx
# → Saved as: Rapport_CGA_2016_page_58_table_1.xlsx
#
# Processing: Rapport_CGA_2016_page_59_table_1.xlsx
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 206
#     204 if __name__ == "__main__":
#     205     start_time = time.time()
# --> 206     main()
#     207     print(f"\nTotal execution time: {time.time() - start_time:.2f} seconds")
#
# Cell In[2], line 183, in main()
#     180     continue
#     182 print(f"\nProcessing: {filename}")
# --> 183 success, output_filename = process_cga_file(input_path, OUTPUT_DIR)
#     185 if success:
#     186     log_processing(filename, "SUCCESS", output_filename)
#
# Cell In[2], line 80, in process_cga_file(input_path, output_dir)
#      78 # Read with explicit handling of potential errors
#      79 try:
# ---> 80     df = pd.read_excel(input_path, header=None, engine='openpyxl')
#      81 except Exception as e:
#      82     raise ValueError(f"Error reading Excel file: {str(e)}")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:536, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     533 finally:
#     534     # make sure to close opened file handles
#     535     if should_close:
# --> 536         io.close()
#     537 return data
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1648, in ExcelFile.close(self)
#    1646 def close(self) -> None:
#    1647     """close io if necessary"""
# -> 1648     self._reader.close()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:600, in BaseExcelReader.close(self)
#     596     elif hasattr(self.book, "release_resources"):
#     597         # xlrd
#     598         # https://github.com/python-excel/xlrd/blob/2.0.1/xlrd/book.py#L548
#     599         self.book.release_resources()
# --> 600 self.handles.close()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:144, in IOHandles.close(self)
#     142     self.created_handles.remove(self.handle)
#     143 for handle in self.created_handles:
# --> 144     handle.close()
#     145 self.created_handles = []
#     146 self.is_wrapped = False
#
# KeyboardInterrupt:
